# %%
import os
import sys
import matplotlib.pyplot as plt
import numpy as np
import scipy.signal as signal
from scipy.misc import electrocardiogram
from scipy.signal import find_peaks
import scipy
import pylab
from os import path
from datetime import datetime

# %%
# Initialization #
file_path = path.relpath("data/updown.txt")
file = open(file_path, "r")
y = []
x = []
dict = {}
i = 0
index = 0

# %%
# Parse the data out of the file #
lines = file.readlines()
for line in lines[:-1]:
    if i > 5: # Disregard header info
        index = i-6
        lineParts = line.strip().split(",") # Split the line into each columns values
        dict[index] = [lineParts[1],lineParts[2],lineParts[3],lineParts[4],lineParts[8]] # Create a dictionary entry w/ the sensor values
        if (index == 0):
            firstTimestamp = lineParts[8].replace(" ", "")

    i += 1
lastTimestamp = dict[index][4].replace(" ", "")
d1 = datetime.strptime(firstTimestamp, "%H:%M:%S.%f")
d2 = datetime.strptime(lastTimestamp, "%H:%M:%S.%f")

duration = d2 - d1
# Out:
# 16:08:30.816

# %%
# Initial data #
x = list(dict.keys())
y = []
for key,value in dict.items(): # Create an array with the dictionary values
    y.append(abs(float((value[1]))))
plt.scatter(x, y)
plt.title("Raw data")
plt.show()

# %%
# Filter the data #
# TODO: find the "minimum duration" (i.e. # of data points) of a tic and parse out all the peaks which don't have (# neighbours) > (min duration)
y = np.asarray(y)
N  = 3    # Filter order
Wn = 0.1 # Cutoff frequency
B, A = signal.butter(N, Wn, output='ba')
smooth_data = signal.filtfilt(B,A, y)
plt.plot(smooth_data,'b-')
plt.title("Filtered data")
plt.show()

# %%
# Find the tics #
thresh = 2000
peaks, _ = find_peaks(y, height=thresh, distance=100, width=10, prominence=1000)
plt.plot(y)
plt.plot(peaks, y[peaks], "x")
plt.plot(np.full((len(y),1), thresh), "--", color="gray")
plt.title("Tic identification")
plt.show()

# %%
# Final analysis #
print("========= FINAL OUTPUT =========")
print("Total duration: " + str(duration))
print("Total number of tics: " + str(len(peaks)))
print("Average number of tics per hour: ")
print("Time of day with highest frequency: ")
# Out:
# ========= FINAL OUTPUT =========
# Total duration: 0:01:32.954000
# Total number of tics: 11
# Average number of tics per hour:
# Time of day with highest frequency:
